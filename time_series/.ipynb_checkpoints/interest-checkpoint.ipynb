# %% [markdown]
# ## Load data

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
import matplotlib.pyplot as plt

# %%
file_s = 'interest.csv'

# %%
df1 = pd.read_csv(file_s, index_col='date') 
df1 = df1.iloc[::-1] # 과거에서 현재로 정렬순서 변경

# %%
print(df1.isnull().values.any()) # 데이터 내 null값 없음
df1.head()
# Out:
# False
#             trea3  trea5  trea10
# date
# 2000-10-20   7.95  8.130   8.610
# 2000-10-21   7.94  8.130   8.610
# 2000-10-23   7.93  8.110   8.480
# 2000-10-24   7.93  8.125   8.455
# 2000-10-25   7.90  8.080   8.415

# %%
df1.plot(figsize=(13,3))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## Normalize data
# 금리의 절대적인 값은 시기에 따라 큰 차이를 나타낸다.
# 과거 값으로 모델을 만들어도 현재에는 금리 레벨이 달라지므로 모델이 제대로 이해하기 어렵다.
# 그러므로 시기별로 금리 값을 normalize 해 줄 필요가 있다.
# 여기서는 n_window 값으로 설정하다. 기본 값으로 20 business days 를 설정한다.
# 이렇게 하면 오늘의 금리 값은 오늘부터 (오늘을 포함한) 과거 20일 간의 평균값으로 나누어 준 값이 된다.

# %%
n_window = 20
roll_df = df1.rolling(n_window).mean()
df_norm = df1/roll_df
df_norm.columns = ['trea3_norm', 'trea5_norm', 'trea10_norm']

# %%
df_norm
# Out:
#             trea3_norm  trea5_norm  trea10_norm
# date
# 2000-10-20         NaN         NaN          NaN
# 2000-10-21         NaN         NaN          NaN
# 2000-10-23         NaN         NaN          NaN
# 2000-10-24         NaN         NaN          NaN
# 2000-10-25         NaN         NaN          NaN
# ...                ...         ...          ...
# 2021-04-09    1.013285    0.993002     0.983893
# 2021-04-12    0.989150    0.974592     0.973956
# 2021-04-13    0.988387    0.987404     0.989349
# 2021-04-14    0.963687    0.968777     0.976710
# 2021-04-15    0.998598    0.996403     0.991561
#
# [5366 rows x 3 columns]

# %%
df_norm.plot(figsize=(13,3))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ## 예측 타겟 값 설정
# 특정 기간 period size 동안의 퍼센트 차이 값을 타겟으로 설정
# 몇 가지 기간에 대해 타겟 값을 구해보자
# (y0 - y_tgt)/y0,
# 예) [5, 10, 20, 30] : 5일 후, 10일 후, 20일 후, 30일 후 예측
# 사용하는 데이터는 tgt_data - (out_period -1) 시점까지 데이터 활용 가능

# %%
df_tgts = {}
periods = [5, 10, 20, 30]
for out_period in periods:
    df_tgt = df1[['trea3', 'trea5', 'trea10']].pct_change(periods=out_period)
    df_tgt.columns = ['trea3_diff', 'trea5_diff', 'trea10_diff']
    df_tgts[str(out_period)] = df_tgt

# %%
print(df1['trea3'][:10])
print(df1['trea3'].pct_change(periods=2)[:10])
# Out:
# date
# 2000-10-20    7.950
# 2000-10-21    7.940
# 2000-10-23    7.930
# 2000-10-24    7.930
# 2000-10-25    7.900
# 2000-10-26    7.865
# 2000-10-27    7.735
# 2000-10-28    7.735
# 2000-10-30    7.725
# 2000-10-31    7.765
# Name: trea3, dtype: float64
# date
# 2000-10-20         NaN
# 2000-10-21         NaN
# 2000-10-23   -0.002516
# 2000-10-24   -0.001259
# 2000-10-25   -0.003783
# 2000-10-26   -0.008197
# 2000-10-27   -0.020886
# 2000-10-28   -0.016529
# 2000-10-30   -0.001293
# 2000-10-31    0.003878
# Name: trea3, dtype: float64

# %%
df_tgts['10'][-20:]
# Out:
#             trea3_diff  trea5_diff  trea10_diff
# date
# 2021-03-19    0.070291    0.124219     0.060150
# 2021-03-22   -0.017391    0.055336     0.009355
# 2021-03-23   -0.059836   -0.006231     0.000983
# 2021-03-24   -0.046809   -0.024204    -0.027027
# 2021-03-25   -0.068085   -0.013072    -0.028190
# 2021-03-26   -0.085366   -0.043614    -0.045131
# 2021-03-29   -0.086066   -0.061728    -0.085967
# 2021-03-30   -0.020426    0.000623    -0.009537
# 2021-03-31   -0.042481   -0.026220    -0.037886
# 2021-04-01   -0.001759   -0.039755    -0.065680
# 2021-04-02    0.004378   -0.030247    -0.029787
# 2021-04-05    0.063717    0.023720     0.024390
# 2021-04-06    0.033130    0.009404     0.019637
# 2021-04-07    0.050893    0.032637     0.040404
# 2021-04-08    0.059361    0.029801     0.029008
# 2021-04-09    0.037333    0.026059     0.007463
# 2021-04-12    0.017937    0.014474     0.015252
# 2021-04-13   -0.016507   -0.029247    -0.025036
# 2021-04-14   -0.023957   -0.045085    -0.031599
# 2021-04-15    0.004405   -0.003185    -0.002475

# %%
df1.rolling(5).mean()
# Out:
#             trea3  trea5  trea10
# date
# 2000-10-20    NaN    NaN     NaN
# 2000-10-21    NaN    NaN     NaN
# 2000-10-23    NaN    NaN     NaN
# 2000-10-24    NaN    NaN     NaN
# 2000-10-25  7.930  8.115   8.514
# 2000-10-26  7.913  8.099   8.458
# 2000-10-27  7.872  8.064   8.384
# 2000-10-28  7.833  8.033   8.336
# 2000-10-30  7.792  7.998   8.293
# 2000-10-31  7.765  7.979   8.262

# %%
for key in df_tgts:
    pass
    #df_tgts[key]['trea10_diff'].plot(ylim=(-0.2, 0.2), figsize=(13,2))
df_tgts['10']['trea10_diff'].plot(ylim=(-0.2, 0.2), figsize=(13,2))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
df2 = pd.concat([df1, df_norm, df_tgts['20']], axis=1)
df2b = df2.dropna()

# %%
df2b.head()
# Out:
#             trea3  trea5  trea10  trea3_norm  trea5_norm  trea10_norm  \
# date
# 2000-11-13  7.135  7.310   7.605    0.927859    0.926783     0.929054
# 2000-11-14  7.155  7.305   7.605    0.935233    0.931018     0.934792
# 2000-11-15  7.245  7.390   7.680    0.951256    0.946193     0.948675
# 2000-11-16  7.290  7.440   7.705    0.961202    0.956790     0.956193
# 2000-11-17  7.275  7.425   7.690    0.963193    0.958900     0.958644
#
#             trea3_diff  trea5_diff  trea10_diff
# date
# 2000-11-13   -0.102516   -0.100861    -0.116725
# 2000-11-14   -0.098866   -0.101476    -0.116725
# 2000-11-15   -0.086381   -0.088779    -0.094340
# 2000-11-16   -0.080706   -0.084308    -0.088705
# 2000-11-17   -0.079114   -0.081064    -0.086156

# %% [markdown]
# get historical data in format of LSTM : (time, input_size)

# %% [markdown]
# ## Make model

# %%
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import sys
lib_s = '/home/adminuser/public/libs/pytorch_examples/basic_networks'
sys.path.append(lib_s)
import generate_model as nets

# %%
class Index_data(Dataset):
    def __init__(self, in_data, tgt, n_window, out_period):
        """
        make it to each n_window old data gives next AMD price
        :param in_data: torch.tensor
        :param tgt: torch.tensor
        """
        self.in_data = in_data[:-1]
        self.tgt = tgt[n_window:] 
        self.n_window = n_window
        self.out_period = out_period
        
    def __getitem__(self, ii):
        """
        nets.Net assumes that data are given as (in_data, tgt)
        normalize by the first element
        """
        """
        normalize once again
        return (self.in_data[ii:ii+self.n_window]/self.in_data[ii], 
                self.tgt[ii+self.out_period-1])
        """
        return (self.in_data[ii:ii+self.n_window], 
                self.tgt[ii+self.out_period-1])
    
    def __len__(self):
        return len(self.tgt) - self.out_period + 1

# %%
df_in = df2b[['trea3_norm', 'trea5_norm', 'trea10_norm']]
df_in_np = df_in.to_numpy(np.single)
df_tgt_np = df2b['trea10_diff'].to_numpy(np.single)

tensor_in = torch.from_numpy(df_in_np)
tensor_tgt = torch.from_numpy(df_tgt_np)

# %%
# input size
n_window = 15
# prediction period
out_period = 10
n_history = len(df_in)
n_train = n_history//10*8
n_test = n_history - n_train
batch_size = 64
train_dset = Index_data(tensor_in[:n_train], tensor_tgt[:n_train], n_window, out_period)
test_dset = Index_data(tensor_in[n_train:], tensor_tgt[n_train:], n_window, out_period)
train_loader = DataLoader(train_dset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## Check testset
# 날짜 차이로 인해 테스트 셋 크기가 줄어드는 지 확인해 보자
# n_window : 15, out_period : 10 으로 인해 총 25개, 마지막날 결과를 보고 예측하므로 -1 --> 24개 차이

# %%
print(n_test)
len(test_dset)
# Out:
# 1074
# 1050

# %%
class Predictor_rnn(nets.Net):
    def __init__(self, rnn=None, downnet=None,
                 loss=None, optimizer=None, device='cuda',
                 dim_input=100, dim_hidden=200):
        """
        net is consists of [embed, rnn, downnet]
        :param downnet: define downstream job
        """
        super(Predictor_rnn, self).__init__(loss=loss, device=device)
        
        if rnn is None:
            self.rnn = nn.LSTM(input_size=dim_input, 
                               hidden_size=dim_hidden, 
                               num_layers= 2,
                               batch_first=True,
                               bidirectional=False)
        else:
            self.rnn = rnn
            
        if downnet is None:
            self.downnet = nets.get_MLP([dim_hidden, dim_hidden*2, 1], 
                                        dropout=0.5, end=True)
        else:
            self.downnet = downnet
        
        self.init_weights()
        
        self.rnn = self.rnn.to(device)
        self.downnet = self.downnet.to(device)
        
        parms = list(self.rnn.parameters())
        parms += list(self.downnet.parameters())
        self.optimizer = optimizer(parms)
        
    
    def set_train(self):
        self.rnn.train()
        self.downnet.train()
        
    def set_eval(self):
        self.rnn.eval()
        self.downnet.eval()
    
    def init_weights(self):
        for ii, layer in enumerate(self.downnet):
            if 'Linear' in str(layer):
                torch.nn.init.xavier_uniform_(self.downnet[ii].weight)

    def forward(self, x):
        #print(x.size())
        #print(self.rnn(x))
        out, hidden = self.rnn(x)
        #print(out[:,-1].size())
        out = self.downnet(out[:,-1]) # choose last output
        return out.view(-1)

    def run_eval(self, data):
        self.set_eval()
        loss = 0
        outs = None
        tgts = None
        with torch.no_grad():
            for i_batch, data_batch in enumerate(data):
                data_in, tgt = data_batch
                data_in = data_in.to(self.device)
                tgt = tgt.to(self.device)
                out = self.forward(data_in)
                #print('loss', loss, self.loss)
                loss += self.loss(out, tgt).cpu().numpy()
                out = out.cpu().numpy()
                #print('loss===', loss)
                tgt = tgt.cpu().numpy()
                if outs is None:
                    outs = out
                    tgts = tgt
                else:
                    outs = np.concatenate((outs, out), axis=0)
                    tgts = np.concatenate((tgts, tgt), axis=0)
        loss /= 1.0*(i_batch+1)
        print('evaluate', 'loss', loss, 'accuracy : define function')
        return outs, tgts, loss

    """
    def run_batch(self, i_batch, data):
        self.optimizer.zero_grad()
        #print(data)
        data_in, tgt = data
        
        data_in = data_in.to(self.device)
        tgt = tgt.to(self.device)
        out = self.forward(data_in)
        loss = self.loss(out, tgt)
        loss.backward()
        self.optimizer.step()
        return loss.detach().cpu().item()
    """
    # If you customize learning, fix run_batch, run_train, run_eval
    #def run_batch(self, i_batch, data):
    #    pass

# %%
dim_input = df_in_np.shape[-1]
dim_hidden = 500
loss = nn.MSELoss() # which combines logsoftmax and nll loss
optimizer = optim.Adam
device = torch.device("cuda:0")

predictor = Predictor_rnn(loss=loss, optimizer=optimizer, 
                          device=device, dim_input=dim_input, 
                          dim_hidden=dim_hidden)

# %%
# normalize twice
predictor.run_train(n_epoch=200, data=train_loader)
# Out:
# epoch 0 loss 0.004979573318790367
# eval_train evaluate loss 0.0037014301285953886 accuracy : define function
# epoch 1 loss 0.0037833252459514273
# eval_train evaluate loss 0.0038936027263138276 accuracy : define function
# epoch 2 loss 0.0032816087938289146
# eval_train evaluate loss 0.0034292791188180226 accuracy : define function
# epoch 3 loss 0.0028513138210261935
# eval_train evaluate loss 0.0024552843933091013 accuracy : define function
# epoch 4 loss 0.0023555645750446327
# eval_train evaluate loss 0.0020016969030431067 accuracy : define function
# epoch 5 loss 0.0024569329194057345
# eval_train evaluate loss 0.002083604146705579 accuracy : define function
# epoch 6 loss 0.002271725559857354
# eval_train evaluate loss 0.002021035304598844 accuracy : define function
# epoch 7 loss 0.0022802650528862627
# eval_train evaluate loss 0.0019547149744023806 accuracy : define function
# epoch 8 loss 0.0021425282005776663
# eval_train evaluate loss 0.0019185397419522502 accuracy : define function
# epoch 9 loss 0.002238482203848882
# eval_train evaluate loss 0.002289474524779996 accuracy : define function
# epoch 10 loss 0.002364036622769964
# eval_train evaluate loss 0.003965671254155129 accuracy : define function
# epoch 11 loss 0.002288347616645772
# eval_train evaluate loss 0.002136067216242872 accuracy : define function
# epoch 12 loss 0.0021394567856036907
# eval_train evaluate loss 0.002078124474900872 accuracy : define function
# epoch 13 loss 0.002098321563689344
# eval_train evaluate loss 0.0020412124985300785 accuracy : define function
# epoch 14 loss 0.0020663901631817667
# eval_train evaluate loss 0.0019108909321253868 accuracy : define function
# epoch 15 loss 0.0019985983363672425
# eval_train evaluate loss 0.0019209847113103675 accuracy : define function
# epoch 16 loss 0.0019677311091669905
# eval_train evaluate loss 0.0018872480558009067 accuracy : define function
# epoch 17 loss 0.0020212657078961605
# eval_train evaluate loss 0.0018930117540589687 accuracy : define function
# epoch 18 loss 0.0019648464208941404
# eval_train evaluate loss 0.0017952190498376627 accuracy : define function
# epoch 19 loss 0.001925966314929746
# eval_train evaluate loss 0.0017397962180452783 accuracy : define function
# epoch 20 loss 0.0019797513794862845
# eval_train evaluate loss 0.002355911192108891 accuracy : define function
# epoch 21 loss 0.0019346158447633706
# eval_train evaluate loss 0.0025730383644964713 accuracy : define function
# epoch 22 loss 0.0019968612755495887
# eval_train evaluate loss 0.001829187045179641 accuracy : define function
# epoch 23 loss 0.0019825743441817477
# eval_train evaluate loss 0.0018073013113158295 accuracy : define function
# epoch 24 loss 0.0019372926482847377
# eval_train evaluate loss 0.0017597964719813595 accuracy : define function
# epoch 25 loss 0.0019232587186869844
# eval_train evaluate loss 0.0018041769152076276 accuracy : define function
# epoch 26 loss 0.001934723521985892
# eval_train evaluate loss 0.0019270532891334994 accuracy : define function
# epoch 27 loss 0.00188801249440537
# eval_train evaluate loss 0.0017559636165318426 accuracy : define function
# epoch 28 loss 0.0019358378060078665
# eval_train evaluate loss 0.0018208695961329253 accuracy : define function
# epoch 29 loss 0.001892734337215826
# eval_train evaluate loss 0.0020481478475006436 accuracy : define function
# epoch 30 loss 0.0018915786875286764
# eval_train evaluate loss 0.0020335673549170814 accuracy : define function
# epoch 31 loss 0.0018708197896910915
# eval_train evaluate loss 0.001798060968511307 accuracy : define function
# epoch 32 loss 0.0018735150441721972
# eval_train evaluate loss 0.002112227855180738 accuracy : define function
# epoch 33 loss 0.0018776839202853726
# eval_train evaluate loss 0.001701672787347169 accuracy : define function
# epoch 34 loss 0.0019099640706901563
# eval_train evaluate loss 0.0017932836616189399 accuracy : define function
# epoch 35 loss 0.0018874397553475713
# eval_train evaluate loss 0.0017456651974552826 accuracy : define function
# epoch 36 loss 0.0018596174490790982
# eval_train evaluate loss 0.0017267434880373748 accuracy : define function
# epoch 37 loss 0.0019630977654579414
# eval_train evaluate loss 0.0021437341468964716 accuracy : define function
# epoch 38 loss 0.0018885002798164515
# eval_train evaluate loss 0.0017799286366398655 accuracy : define function
# epoch 39 loss 0.0019081910088686134
# eval_train evaluate loss 0.0017471029657745427 accuracy : define function
# epoch 40 loss 0.001977366306680018
# eval_train evaluate loss 0.0019034540676859332 accuracy : define function
# epoch 41 loss 0.0019727452560814457
# eval_train evaluate loss 0.0017408166157165126 accuracy : define function
# epoch 42 loss 0.001881719587732162
# eval_train evaluate loss 0.0018045364778294269 accuracy : define function
# epoch 43 loss 0.001860628202522813
# eval_train evaluate loss 0.001888162552017663 accuracy : define function
# epoch 44 loss 0.001830135406092254
# eval_train evaluate loss 0.0017116037180035638 accuracy : define function
# epoch 45 loss 0.0018174303348051078
# eval_train evaluate loss 0.0023735682532163476 accuracy : define function
# epoch 46 loss 0.001931192894612175
# eval_train evaluate loss 0.0017889476513295475 accuracy : define function
# epoch 47 loss 0.0018411905091228102
# eval_train evaluate loss 0.002386523931940545 accuracy : define function
# epoch 48 loss 0.001970830883434626
# eval_train evaluate loss 0.0020489805176464922 accuracy : define function
# epoch 49 loss 0.0019148245068100183
# eval_train evaluate loss 0.001719850281413311 accuracy : define function
# epoch 50 loss 0.0018356685464117509
# eval_train evaluate loss 0.001962593122413243 accuracy : define function
# epoch 51 loss 0.0018475788815725427
# eval_train evaluate loss 0.0018406472066347834 accuracy : define function
# epoch 52 loss 0.0018558088001975818
# eval_train evaluate loss 0.0016492993384947194 accuracy : define function
# epoch 53 loss 0.001888865199280597
# eval_train evaluate loss 0.0016854606176128805 accuracy : define function
# epoch 54 loss 0.0018287392232372466
# eval_train evaluate loss 0.0016675981321135787 accuracy : define function
# epoch 55 loss 0.0018307817178959056
# eval_train evaluate loss 0.001984882078119623 accuracy : define function
# epoch 56 loss 0.0019940180033306354
# eval_train evaluate loss 0.0019472312536646626 accuracy : define function
# epoch 57 loss 0.001828028710989921
# eval_train evaluate loss 0.0017760995933577529 accuracy : define function
# epoch 58 loss 0.0017838032773709787
# eval_train evaluate loss 0.0017155026652113494 accuracy : define function
# epoch 59 loss 0.0017694860371872227
# eval_train evaluate loss 0.0016640690172702742 accuracy : define function
# epoch 60 loss 0.0018249744542443486
# eval_train evaluate loss 0.0017365721851907003 accuracy : define function
# epoch 61 loss 0.0018471409306069142
# eval_train evaluate loss 0.0016952112939125344 accuracy : define function
# epoch 62 loss 0.0018624689216280718
# eval_train evaluate loss 0.001958307328828569 accuracy : define function
# epoch 63 loss 0.0017958226823942987
# eval_train evaluate loss 0.0017592021795823725 accuracy : define function
# epoch 64 loss 0.001796979667382565
# eval_train evaluate loss 0.0016979606537176157 accuracy : define function
# epoch 65 loss 0.0017995380773904053
# eval_train evaluate loss 0.0018720934515012735 accuracy : define function
# epoch 66 loss 0.0018196114410173648
# eval_train evaluate loss 0.0017392617318459523 accuracy : define function
# epoch 67 loss 0.001791125458818096
# eval_train evaluate loss 0.001663708688392401 accuracy : define function
# epoch 68 loss 0.001894286108279684
# eval_train evaluate loss 0.0019793455165796983 accuracy : define function
# epoch 69 loss 0.0020508792949840426
# eval_train evaluate loss 0.001883448756633521 accuracy : define function
# epoch 70 loss 0.0018765542920289645
# eval_train evaluate loss 0.0018859935729806103 accuracy : define function
# epoch 71 loss 0.001844025740865618
# eval_train evaluate loss 0.0017132985391723576 accuracy : define function
# epoch 72 loss 0.001882225307184202
# eval_train evaluate loss 0.0019256872178833764 accuracy : define function
# epoch 73 loss 0.0018862938350275049
# eval_train evaluate loss 0.0016894809312687548 accuracy : define function
# epoch 74 loss 0.0018418329088503856
# eval_train evaluate loss 0.0017827455772768095 accuracy : define function
# epoch 75 loss 0.0017631062186573311
# eval_train evaluate loss 0.0017399168217123778 accuracy : define function
# epoch 76 loss 0.0018314565436344649
# eval_train evaluate loss 0.001667622279605147 accuracy : define function
# epoch 77 loss 0.0018211292500830076
# eval_train evaluate loss 0.001849787092573051 accuracy : define function
# epoch 78 loss 0.0017596096601406696
# eval_train evaluate loss 0.0016813322079868348 accuracy : define function
# epoch 79 loss 0.0018028555865357838
# eval_train evaluate loss 0.0016979965947763022 accuracy : define function
# epoch 80 loss 0.0018787475219413415
# eval_train evaluate loss 0.0017731969866818234 accuracy : define function
# epoch 81 loss 0.0018222076938237384
# eval_train evaluate loss 0.0017789145167082993 accuracy : define function
# epoch 82 loss 0.001808032909505514
# eval_train evaluate loss 0.0016813903391958952 accuracy : define function
# epoch 83 loss 0.0017754238892916535
# eval_train evaluate loss 0.0016511482987622383 accuracy : define function
# epoch 84 loss 0.001780126655627209
# eval_train evaluate loss 0.0016482825453546066 accuracy : define function
# epoch 85 loss 0.0017604028585422506
# eval_train evaluate loss 0.0017220521590728035 accuracy : define function
# epoch 86 loss 0.0018452916775635484
# eval_train evaluate loss 0.0016239655165891371 accuracy : define function
# epoch 87 loss 0.0017275526405506727
# eval_train evaluate loss 0.001658892825440462 accuracy : define function
# epoch 88 loss 0.0018303619529148425
# eval_train evaluate loss 0.002019807138591449 accuracy : define function
# epoch 89 loss 0.0019078241607327182
# eval_train evaluate loss 0.0019167087687207247 accuracy : define function
# epoch 90 loss 0.0018262597680119659
# eval_train evaluate loss 0.0019475600035833334 accuracy : define function
# epoch 91 loss 0.0018282430741671863
# eval_train evaluate loss 0.0016404500625568873 accuracy : define function
# epoch 92 loss 0.0017464434616823695
# eval_train evaluate loss 0.0017569374810876464 accuracy : define function
# epoch 93 loss 0.001766199328582178
# eval_train evaluate loss 0.0018284337320573518 accuracy : define function
# epoch 94 loss 0.0017971976568102281
# eval_train evaluate loss 0.001931247913883304 accuracy : define function
# epoch 95 loss 0.0018682430373198951
# eval_train evaluate loss 0.0016405983131253785 accuracy : define function
# epoch 96 loss 0.001777131782858563
# eval_train evaluate loss 0.001617800418301416 accuracy : define function
# epoch 97 loss 0.0018013815218304744
# eval_train evaluate loss 0.001632559851659879 accuracy : define function
# epoch 98 loss 0.001776063419468423
# eval_train evaluate loss 0.001811478323469967 accuracy : define function
# epoch 99 loss 0.0017828936149963915
# eval_train evaluate loss 0.001779246850307586 accuracy : define function
# epoch 100 loss 0.0018614424277903206
# eval_train evaluate loss 0.0017263017005787523 accuracy : define function
# epoch 101 loss 0.001797216191171988
# eval_train evaluate loss 0.001656902564772919 accuracy : define function
# epoch 102 loss 0.0018069748054328027
# eval_train evaluate loss 0.0016147565685643522 accuracy : define function
# epoch 103 loss 0.0018339644971567747
# eval_train evaluate loss 0.001919346666936554 accuracy : define function
# epoch 104 loss 0.0018122120657866237
# eval_train evaluate loss 0.001907413246791198 accuracy : define function
# epoch 105 loss 0.0017756916158624104
# eval_train evaluate loss 0.001695454012908375 accuracy : define function
# epoch 106 loss 0.0017352562550622137
# eval_train evaluate loss 0.0017002202716391924 accuracy : define function
# epoch 107 loss 0.0017198336175156396
# eval_train evaluate loss 0.0017230987805984359 accuracy : define function
# epoch 108 loss 0.0017327171378532676
# eval_train evaluate loss 0.0016584812764272984 accuracy : define function
# epoch 109 loss 0.0017214254945266381
# eval_train evaluate loss 0.0016248824540525675 accuracy : define function
# epoch 110 loss 0.001742640716100195
# eval_train evaluate loss 0.0016366510413962402 accuracy : define function
# epoch 111 loss 0.00176706326666719
# eval_train evaluate loss 0.0018255023647155335 accuracy : define function
# epoch 112 loss 0.0017493308605209216
# eval_train evaluate loss 0.0016501789839604675 accuracy : define function
# epoch 113 loss 0.001796808424788013
# eval_train evaluate loss 0.001607946487692699 accuracy : define function
# epoch 114 loss 0.0017942082442676842
# eval_train evaluate loss 0.0015991299844055034 accuracy : define function
# epoch 115 loss 0.0018276188039540577
# eval_train evaluate loss 0.0018468626180608103 accuracy : define function
# epoch 116 loss 0.0018364607917714809
# eval_train evaluate loss 0.0018055611324788474 accuracy : define function
# epoch 117 loss 0.0018011414456361933
# eval_train evaluate loss 0.0017470897248348415 accuracy : define function
# epoch 118 loss 0.0019290991676554306
# eval_train evaluate loss 0.001669708266680532 accuracy : define function
# epoch 119 loss 0.001946011604219953
# eval_train evaluate loss 0.0019042053044453931 accuracy : define function
# epoch 120 loss 0.0017622369689060681
# eval_train evaluate loss 0.001619376362051203 accuracy : define function
# epoch 121 loss 0.001829713975677072
# eval_train evaluate loss 0.002089293223611121 accuracy : define function
# epoch 122 loss 0.0018026431450800999
# eval_train evaluate loss 0.0016102866198408848 accuracy : define function
# epoch 123 loss 0.001735773106077825
# eval_train evaluate loss 0.001597711028454742 accuracy : define function
# epoch 124 loss 0.0018377889194456276
# eval_train evaluate loss 0.001795800169929862 accuracy : define function
# epoch 125 loss 0.0017403325703648379
# eval_train evaluate loss 0.0018012869700011033 accuracy : define function
# epoch 126 loss 0.001815158011975573
# eval_train evaluate loss 0.0016872234479176687 accuracy : define function
# epoch 127 loss 0.001748870614283621
# eval_train evaluate loss 0.0016388332605042231 accuracy : define function
# epoch 128 loss 0.0017619376129873875
# eval_train evaluate loss 0.0016449372555170931 accuracy : define function
# epoch 129 loss 0.0017279809750894556
# eval_train evaluate loss 0.0017711745623721561 accuracy : define function
# epoch 130 loss 0.0017614376004924303
# eval_train evaluate loss 0.0016444914499923254 accuracy : define function
# epoch 131 loss 0.0017465724915599644
# eval_train evaluate loss 0.001630645329584437 accuracy : define function
# epoch 132 loss 0.0017455596938979491
# eval_train evaluate loss 0.001851448226275284 accuracy : define function
# epoch 133 loss 0.0017961461475786212
# eval_train evaluate loss 0.0016628373049394187 accuracy : define function
# epoch 134 loss 0.0017682017772388992
# eval_train evaluate loss 0.0016230520420471458 accuracy : define function
# epoch 135 loss 0.0017761436748012567
# eval_train evaluate loss 0.0016860267149159378 accuracy : define function
# epoch 136 loss 0.0017538707731152648
# eval_train evaluate loss 0.0015939041657665215 accuracy : define function
# epoch 137 loss 0.0017881530385686836
# eval_train evaluate loss 0.0020650986811396347 accuracy : define function
# epoch 138 loss 0.001805750125803665
# eval_train evaluate loss 0.0019084513587043135 accuracy : define function
# epoch 139 loss 0.001782469394957341
# eval_train evaluate loss 0.001754259155479385 accuracy : define function
# epoch 140 loss 0.0017594452009105416
# eval_train evaluate loss 0.002064641874366954 accuracy : define function
# epoch 141 loss 0.0017646870075433113
# eval_train evaluate loss 0.0016107437002764486 accuracy : define function
# epoch 142 loss 0.0018034581122780913
# eval_train evaluate loss 0.0017063066688255031 accuracy : define function
# epoch 143 loss 0.001826366280212498
# eval_train evaluate loss 0.0017420122497228544 accuracy : define function
# epoch 144 loss 0.0017800534442901166
# eval_train evaluate loss 0.0015994407316503017 accuracy : define function
# epoch 145 loss 0.0017200506356572593
# eval_train evaluate loss 0.0018090684229243937 accuracy : define function
# epoch 146 loss 0.0017519538575755571
# eval_train evaluate loss 0.0017505818578317316 accuracy : define function
# epoch 147 loss 0.0016957845238259814
# eval_train evaluate loss 0.0016455553400802857 accuracy : define function
# epoch 148 loss 0.0017999190100426994
# eval_train evaluate loss 0.0016307702336682758 accuracy : define function
# epoch 149 loss 0.001696727777233542
# eval_train evaluate loss 0.0016008456030846643 accuracy : define function
# epoch 150 loss 0.001763376053735447
# eval_train evaluate loss 0.0017716439819630626 accuracy : define function
# epoch 151 loss 0.0017929726155168975
# eval_train evaluate loss 0.001885987724413845 accuracy : define function
# epoch 152 loss 0.0018265866422539215
# eval_train evaluate loss 0.001619789180338883 accuracy : define function
# epoch 153 loss 0.0017362105974635638
# eval_train evaluate loss 0.0016569212754952041 accuracy : define function
# epoch 154 loss 0.0017033062333157703
# eval_train evaluate loss 0.0017326600065996954 accuracy : define function
# epoch 155 loss 0.001822365529543317
# eval_train evaluate loss 0.0016076310030393192 accuracy : define function
# epoch 156 loss 0.001746861333611296
# eval_train evaluate loss 0.001661012310590317 accuracy : define function
# epoch 157 loss 0.0017346476687730027
# eval_train evaluate loss 0.0015952548893071266 accuracy : define function
# epoch 158 loss 0.0017241131594237773
# eval_train evaluate loss 0.0015996562424741353 accuracy : define function
# epoch 159 loss 0.0018159002439230125
# eval_train evaluate loss 0.0018122732663638334 accuracy : define function
# epoch 160 loss 0.0017925366966067744
# eval_train evaluate loss 0.001671598249448658 accuracy : define function
# epoch 161 loss 0.0018029546220925874
# eval_train evaluate loss 0.001662659765492235 accuracy : define function
# epoch 162 loss 0.001723936751116512
# eval_train evaluate loss 0.001843446201936745 accuracy : define function
# epoch 163 loss 0.0017931615428151146
# eval_train evaluate loss 0.0016336281003722392 accuracy : define function
# epoch 164 loss 0.00175186944604198
# eval_train evaluate loss 0.001597184964122056 accuracy : define function
# epoch 165 loss 0.0016870479248881117
# eval_train evaluate loss 0.001703558486205206 accuracy : define function
# epoch 166 loss 0.0017143429618384411
# eval_train evaluate loss 0.0016123205796926658 accuracy : define function
# epoch 167 loss 0.001722021257755027
# eval_train evaluate loss 0.001594193465660201 accuracy : define function
# epoch 168 loss 0.0017033193404647285
# eval_train evaluate loss 0.0015825024274275152 accuracy : define function
# epoch 169 loss 0.0018238979687135834
# eval_train evaluate loss 0.0018952753744088113 accuracy : define function
# epoch 170 loss 0.0017641208650641589
# eval_train evaluate loss 0.0016320985185899841 accuracy : define function
# epoch 171 loss 0.0017017775906750293
# eval_train evaluate loss 0.00179593787014262 accuracy : define function
# epoch 172 loss 0.0017371862820947349
# eval_train evaluate loss 0.0016673751455147875 accuracy : define function
# epoch 173 loss 0.00173265555327925
# eval_train evaluate loss 0.001611829394780433 accuracy : define function
# epoch 174 loss 0.0017317810300876623
# eval_train evaluate loss 0.0018666234525935308 accuracy : define function
# epoch 175 loss 0.001798920533202811
# eval_train evaluate loss 0.0015879302996266356 accuracy : define function
# epoch 176 loss 0.001724621744082768
# eval_train evaluate loss 0.0017039955232236812 accuracy : define function
# epoch 177 loss 0.0017181852295536048
# eval_train evaluate loss 0.001566315293937588 accuracy : define function
# epoch 178 loss 0.001757628074152145
# eval_train evaluate loss 0.00161396221990989 accuracy : define function
# epoch 179 loss 0.0016906525315925369
# eval_train evaluate loss 0.001678361477497131 accuracy : define function
# epoch 180 loss 0.001751392136272321
# eval_train evaluate loss 0.0018557017641281015 accuracy : define function
# epoch 181 loss 0.0018012623386040553
# eval_train evaluate loss 0.0016479649435061571 accuracy : define function
# epoch 182 loss 0.0018166793152384127
# eval_train evaluate loss 0.0018431475340847426 accuracy : define function
# epoch 183 loss 0.001832313191861526
# eval_train evaluate loss 0.0016034691561527773 accuracy : define function
# epoch 184 loss 0.0017115907698397094
# eval_train evaluate loss 0.0016429301432973303 accuracy : define function
# epoch 185 loss 0.001687784621895138
# eval_train evaluate loss 0.001572958503870655 accuracy : define function
# epoch 186 loss 0.0017672041639574428
# eval_train evaluate loss 0.0017964055243907357 accuracy : define function
# epoch 187 loss 0.0017388252829854836
# eval_train evaluate loss 0.0015663110465158833 accuracy : define function
# epoch 188 loss 0.0016872848917507746
# eval_train evaluate loss 0.0016124679163140036 accuracy : define function
# epoch 189 loss 0.0017152644942319993
# eval_train evaluate loss 0.0015721031909447108 accuracy : define function
# epoch 190 loss 0.0016869078112293535
# eval_train evaluate loss 0.0016062644400647772 accuracy : define function
# epoch 191 loss 0.0017142752463470644
# eval_train evaluate loss 0.0016289913849627127 accuracy : define function
# epoch 192 loss 0.0017048418765137
# eval_train evaluate loss 0.0015988278267001594 accuracy : define function
# epoch 193 loss 0.0017745907117835066
# eval_train evaluate loss 0.0017841697006778263 accuracy : define function
# epoch 194 loss 0.0017773082476359471
# eval_train evaluate loss 0.0017276828093871252 accuracy : define function
# epoch 195 loss 0.0017849659336967142
# eval_train evaluate loss 0.0016808985895824743 accuracy : define function
# epoch 196 loss 0.0017597309397116526
# eval_train evaluate loss 0.0016061966316148972 accuracy : define function
# epoch 197 loss 0.0018352422439284733
# eval_train evaluate loss 0.001690564780503011 accuracy : define function
# epoch 198 loss 0.0017192952774478984
# eval_train evaluate loss 0.001581928746621889 accuracy : define function
# epoch 199 loss 0.0016984592753101085
# eval_train evaluate loss 0.0015504181683897527 accuracy : define function

# %%
# normalize once
predictor.run_train(n_epoch=200, data=train_loader)
# Out:
# epoch 0 loss 0.001997315387394446
# eval_train evaluate loss 0.001814418908472715 accuracy : define function
# epoch 1 loss 0.0019194355370032031
# eval_train evaluate loss 0.0016776887533157619 accuracy : define function
# epoch 2 loss 0.001842865786417874
# eval_train evaluate loss 0.0019993969524251436 accuracy : define function
# epoch 3 loss 0.0018440244151209828
# eval_train evaluate loss 0.001746977837547771 accuracy : define function
# epoch 4 loss 0.0017874574231386963
# eval_train evaluate loss 0.0016213672699531847 accuracy : define function
# epoch 5 loss 0.0017829591099089428
# eval_train evaluate loss 0.0016762039419124597 accuracy : define function
# epoch 6 loss 0.0018311398661584218
# eval_train evaluate loss 0.0016369917464734457 accuracy : define function
# epoch 7 loss 0.0019356873192226708
# eval_train evaluate loss 0.0016391556197429883 accuracy : define function
# epoch 8 loss 0.001756349458609388
# eval_train evaluate loss 0.0016175756402967026 accuracy : define function
# epoch 9 loss 0.0018578620137535591
# eval_train evaluate loss 0.0016369569973686516 accuracy : define function
# epoch 10 loss 0.0017550899073787366
# eval_train evaluate loss 0.0016001140622338697 accuracy : define function
# epoch 11 loss 0.0017709193904119642
# eval_train evaluate loss 0.001723212535743282 accuracy : define function
# epoch 12 loss 0.0017739516238112058
# eval_train evaluate loss 0.0017849858207350125 accuracy : define function
# epoch 13 loss 0.0017271729198340049
# eval_train evaluate loss 0.0016027477086841392 accuracy : define function
# epoch 14 loss 0.0017203306049497714
# eval_train evaluate loss 0.0016880131790539556 accuracy : define function
# epoch 15 loss 0.001740621835507675
# eval_train evaluate loss 0.0017504417754487314 accuracy : define function
# epoch 16 loss 0.0017194687180332284
# eval_train evaluate loss 0.0018317707894203155 accuracy : define function
# epoch 17 loss 0.001760312251802256
# eval_train evaluate loss 0.0016540116978003019 accuracy : define function
# epoch 18 loss 0.0017530969743714182
# eval_train evaluate loss 0.0016408201668467095 accuracy : define function
# epoch 19 loss 0.0017030125070335482
# eval_train evaluate loss 0.0016082254118536278 accuracy : define function
# epoch 20 loss 0.0017108829768457965
# eval_train evaluate loss 0.0016324340292850315 accuracy : define function
# epoch 21 loss 0.001810102730489044
# eval_train evaluate loss 0.0016732523843312442 accuracy : define function
# epoch 22 loss 0.001726580234661476
# eval_train evaluate loss 0.0016459719601101173 accuracy : define function
# epoch 23 loss 0.0017648297118773655
# eval_train evaluate loss 0.0018013207678015885 accuracy : define function
# epoch 24 loss 0.0017752035811140355
# eval_train evaluate loss 0.0020520078624709885 accuracy : define function
# epoch 25 loss 0.0018183774525063364
# eval_train evaluate loss 0.0016244341925120175 accuracy : define function
# epoch 26 loss 0.0017183521126549858
# eval_train evaluate loss 0.0016100997237294022 accuracy : define function
# epoch 27 loss 0.0018110041317196369
# eval_train evaluate loss 0.0015695927197238737 accuracy : define function
# epoch 28 loss 0.0017278674475626268
# eval_train evaluate loss 0.0016822954500789074 accuracy : define function
# epoch 29 loss 0.0017053565703707733
# eval_train evaluate loss 0.0016431896009051533 accuracy : define function
# epoch 30 loss 0.0017457717982704627
# eval_train evaluate loss 0.00165166946757001 accuracy : define function
# epoch 31 loss 0.0016948538015721672
# eval_train evaluate loss 0.0015521168903405986 accuracy : define function
# epoch 32 loss 0.0016616337963922033
# eval_train evaluate loss 0.001634422514184531 accuracy : define function
# epoch 33 loss 0.0016989173869769187
# eval_train evaluate loss 0.0015600175942544505 accuracy : define function
# epoch 34 loss 0.0017577998145525135
# eval_train evaluate loss 0.0015626105709251627 accuracy : define function
# epoch 35 loss 0.001698636204880009
# eval_train evaluate loss 0.001728718106482011 accuracy : define function
# epoch 36 loss 0.0017095161002449023
# eval_train evaluate loss 0.0016922132501295253 accuracy : define function
# epoch 37 loss 0.0017269343440073418
# eval_train evaluate loss 0.001575822715209658 accuracy : define function
# epoch 38 loss 0.0019533354571825865
# eval_train evaluate loss 0.0017590618939069447 accuracy : define function
# epoch 39 loss 0.001819896571678735
# eval_train evaluate loss 0.0016030478438904593 accuracy : define function
# epoch 40 loss 0.0017877957017383359
# eval_train evaluate loss 0.0016626259042714624 accuracy : define function
# epoch 41 loss 0.0017251692965988125
# eval_train evaluate loss 0.001703161358791612 accuracy : define function
# epoch 42 loss 0.0017208975293228764
# eval_train evaluate loss 0.001576076562293986 accuracy : define function
# epoch 43 loss 0.0017846961394508384
# eval_train evaluate loss 0.0015855958170966425 accuracy : define function
# epoch 44 loss 0.0016943103348864104
# eval_train evaluate loss 0.0018072868393275386 accuracy : define function
# epoch 45 loss 0.0017602696611698884
# eval_train evaluate loss 0.001560545867871938 accuracy : define function
# epoch 46 loss 0.001667958229029579
# eval_train evaluate loss 0.001593091252343312 accuracy : define function
# epoch 47 loss 0.0016998766066589907
# eval_train evaluate loss 0.0017675398814200021 accuracy : define function
# epoch 48 loss 0.0017584675711009707
# eval_train evaluate loss 0.0016799811960142384 accuracy : define function
# epoch 49 loss 0.0017088227696827989
# eval_train evaluate loss 0.001531866707477663 accuracy : define function
# epoch 50 loss 0.001672622274239061
# eval_train evaluate loss 0.0016574457456329976 accuracy : define function
# epoch 51 loss 0.001700577486841592
# eval_train evaluate loss 0.0016402605731637954 accuracy : define function
# epoch 52 loss 0.0016840557218529284
# eval_train evaluate loss 0.0015307664914654374 accuracy : define function
# epoch 53 loss 0.0017308694894300467
# eval_train evaluate loss 0.0015811946507154116 accuracy : define function
# epoch 54 loss 0.0016927144632660853
# eval_train evaluate loss 0.0015227102088992163 accuracy : define function
# epoch 55 loss 0.001632579098413907
# eval_train evaluate loss 0.0015471160920934558 accuracy : define function
# epoch 56 loss 0.001694712811323411
# eval_train evaluate loss 0.001510359114035964 accuracy : define function
# epoch 57 loss 0.001742109354870366
# eval_train evaluate loss 0.0016269925338869443 accuracy : define function
# epoch 58 loss 0.001734153409279994
# eval_train evaluate loss 0.0017285539452403561 accuracy : define function
# epoch 59 loss 0.001717941793821641
# eval_train evaluate loss 0.001604149310064238 accuracy : define function
# epoch 60 loss 0.002433306221335904
# eval_train evaluate loss 0.002129340103876068 accuracy : define function
# epoch 61 loss 0.0018629320487102022
# eval_train evaluate loss 0.001745219945337679 accuracy : define function
# epoch 62 loss 0.001757068927886326
# eval_train evaluate loss 0.0016723969402208702 accuracy : define function
# epoch 63 loss 0.0017377118242960145
# eval_train evaluate loss 0.001604225403114931 accuracy : define function
# epoch 64 loss 0.0017173701893788442
# eval_train evaluate loss 0.0015722733536568372 accuracy : define function
# epoch 65 loss 0.0017000979869000947
# eval_train evaluate loss 0.0016247605289846881 accuracy : define function
# epoch 66 loss 0.0017168470962431782
# eval_train evaluate loss 0.0015468411382162637 accuracy : define function
# epoch 67 loss 0.001760197502783319
# eval_train evaluate loss 0.0017087094211228082 accuracy : define function
# epoch 68 loss 0.0017041552745834438
# eval_train evaluate loss 0.0015931047678146679 accuracy : define function
# epoch 69 loss 0.0016812881213307048
# eval_train evaluate loss 0.0016077516379821768 accuracy : define function
# epoch 70 loss 0.0017403741766795961
# eval_train evaluate loss 0.0015841007967646332 accuracy : define function
# epoch 71 loss 0.0016935726066481377
# eval_train evaluate loss 0.0016758766089593853 accuracy : define function
# epoch 72 loss 0.001664746868069659
# eval_train evaluate loss 0.001561075953745853 accuracy : define function
# epoch 73 loss 0.0016486548936800725
# eval_train evaluate loss 0.0015491228263978083 accuracy : define function
# epoch 74 loss 0.0016542703570075223
# eval_train evaluate loss 0.001587851251016802 accuracy : define function
# epoch 75 loss 0.0017291497823142849
# eval_train evaluate loss 0.0015690193186625283 accuracy : define function
# epoch 76 loss 0.0016772039947030482
# eval_train evaluate loss 0.0016134601866534509 accuracy : define function
# epoch 77 loss 0.0016643788323237269
# eval_train evaluate loss 0.0015727318371576604 accuracy : define function
# epoch 78 loss 0.0016068703818148864
# eval_train evaluate loss 0.0015101347860546589 accuracy : define function
# epoch 79 loss 0.0018071020334792225
# eval_train evaluate loss 0.0015249042302620276 accuracy : define function
# epoch 80 loss 0.0016829677624627948
# eval_train evaluate loss 0.0015078154792175142 accuracy : define function
# epoch 81 loss 0.0016160750815491956
# eval_train evaluate loss 0.0014776055529060314 accuracy : define function
# epoch 82 loss 0.0015906445567371017
# eval_train evaluate loss 0.0015297688304015727 accuracy : define function
# epoch 83 loss 0.0016681657271779406
# eval_train evaluate loss 0.0015744611554876415 accuracy : define function
# epoch 84 loss 0.0016498443819999472
# eval_train evaluate loss 0.001520771031101137 accuracy : define function
# epoch 85 loss 0.0016355068977129883
# eval_train evaluate loss 0.0015012165696582577 accuracy : define function
# epoch 86 loss 0.0016000345879262174
# eval_train evaluate loss 0.001481951323838265 accuracy : define function
# epoch 87 loss 0.0016035056306368935
# eval_train evaluate loss 0.001565945818638012 accuracy : define function
# epoch 88 loss 0.0017079946935983068
# eval_train evaluate loss 0.0015141820489887649 accuracy : define function
# epoch 89 loss 0.001650637531750349
# eval_train evaluate loss 0.0016255145996753404 accuracy : define function
# epoch 90 loss 0.001650076467238033
# eval_train evaluate loss 0.0016756979157842363 accuracy : define function
# epoch 91 loss 0.0016171225223259361
# eval_train evaluate loss 0.001534402415628976 accuracy : define function
# epoch 92 loss 0.0017465756321673406
# eval_train evaluate loss 0.001557232951050374 accuracy : define function
# epoch 93 loss 0.0016505662039089115
# eval_train evaluate loss 0.0017433805458956578 accuracy : define function
# epoch 94 loss 0.0016554893974437199
# eval_train evaluate loss 0.0015626770623181183 accuracy : define function
# epoch 95 loss 0.0016426648266974892
# eval_train evaluate loss 0.0015537219761467692 accuracy : define function
# epoch 96 loss 0.001619053630978425
# eval_train evaluate loss 0.0015678389767643565 accuracy : define function
# epoch 97 loss 0.0016154003192309235
# eval_train evaluate loss 0.0015770323590180877 accuracy : define function
# epoch 98 loss 0.0015941815904286036
# eval_train evaluate loss 0.0014430529867132096 accuracy : define function
# epoch 99 loss 0.0016223626626558157
# eval_train evaluate loss 0.0015978954303245158 accuracy : define function
# epoch 100 loss 0.001621251022304172
# eval_train evaluate loss 0.001634825517096793 accuracy : define function
# epoch 101 loss 0.001675251495169559
# eval_train evaluate loss 0.0015676404095824753 accuracy : define function
# epoch 102 loss 0.0016437244354816738
# eval_train evaluate loss 0.0014650357814172089 accuracy : define function
# epoch 103 loss 0.0016466621300831104
# eval_train evaluate loss 0.0015424632635871087 accuracy : define function
# epoch 104 loss 0.0016051989497005272
# eval_train evaluate loss 0.0016989593911888217 accuracy : define function
# epoch 105 loss 0.001645278575684208
# eval_train evaluate loss 0.0017181803496665697 accuracy : define function
# epoch 106 loss 0.0017329169604093282
# eval_train evaluate loss 0.0017033725822302721 accuracy : define function
# epoch 107 loss 0.001688612294869859
# eval_train evaluate loss 0.0016564706161465328 accuracy : define function
# epoch 108 loss 0.0016288108048168248
# eval_train evaluate loss 0.0015448481044315024 accuracy : define function
# epoch 109 loss 0.0016351835480752164
# eval_train evaluate loss 0.0014840584463759589 accuracy : define function
# epoch 110 loss 0.001596445652114144
# eval_train evaluate loss 0.0015521830559444073 accuracy : define function
# epoch 111 loss 0.0015831780576480747
# eval_train evaluate loss 0.0014407698902537795 accuracy : define function
# epoch 112 loss 0.0016445454927647848
# eval_train evaluate loss 0.0015374257397810136 accuracy : define function
# epoch 113 loss 0.001612411359318101
# eval_train evaluate loss 0.0017708928894195983 accuracy : define function
# epoch 114 loss 0.0016044855566083717
# eval_train evaluate loss 0.0016423094472083361 accuracy : define function
# epoch 115 loss 0.0016778884976824274
# eval_train evaluate loss 0.0016190250631797113 accuracy : define function
# epoch 116 loss 0.0017368202549474898
# eval_train evaluate loss 0.0015884043402108017 accuracy : define function
# epoch 117 loss 0.001672235481725978
# eval_train evaluate loss 0.001479174376208224 accuracy : define function
# epoch 118 loss 0.0016534657134160177
# eval_train evaluate loss 0.0016658157023337128 accuracy : define function
# epoch 119 loss 0.00168131518007409
# eval_train evaluate loss 0.001472337244412125 accuracy : define function
# epoch 120 loss 0.0015929757370683017
# eval_train evaluate loss 0.0014326131004325823 accuracy : define function
# epoch 121 loss 0.0015586819421541669
# eval_train evaluate loss 0.0014652169540649586 accuracy : define function
# epoch 122 loss 0.0015784876878067518
# eval_train evaluate loss 0.001611395260326064 accuracy : define function
# epoch 123 loss 0.001591573182646352
# eval_train evaluate loss 0.0014314523189147906 accuracy : define function
# epoch 124 loss 0.0016345741451412106
# eval_train evaluate loss 0.0014877101517657735 accuracy : define function
# epoch 125 loss 0.0016121296768090618
# eval_train evaluate loss 0.0015857680422712618 accuracy : define function
# epoch 126 loss 0.0015881734069631394
# eval_train evaluate loss 0.0014734640196243773 accuracy : define function
# epoch 127 loss 0.0016275828169074965
# eval_train evaluate loss 0.001505884353189604 accuracy : define function
# epoch 128 loss 0.0015875650065909348
# eval_train evaluate loss 0.0014680463311596036 accuracy : define function
# epoch 129 loss 0.0015943266517385395
# eval_train evaluate loss 0.0014169219969910806 accuracy : define function
# epoch 130 loss 0.0016169185904827692
# eval_train evaluate loss 0.0014683241684879385 accuracy : define function
# epoch 131 loss 0.0015886349711261357
# eval_train evaluate loss 0.0015431493199291402 accuracy : define function
# epoch 132 loss 0.0016232949851859193
# eval_train evaluate loss 0.0015403762470180197 accuracy : define function
# epoch 133 loss 0.0015874794013659233
# eval_train evaluate loss 0.0014728165853685185 accuracy : define function
# epoch 134 loss 0.0016676748637109995
# eval_train evaluate loss 0.0016199259162157664 accuracy : define function
# epoch 135 loss 0.0016185141293637787
# eval_train evaluate loss 0.0016307185843600822 accuracy : define function
# epoch 136 loss 0.0016228136486624047
# eval_train evaluate loss 0.0016255640457801298 accuracy : define function
# epoch 137 loss 0.0015981919922754724
# eval_train evaluate loss 0.0014190065419065086 accuracy : define function
# epoch 138 loss 0.001628430964209751
# eval_train evaluate loss 0.0017258568628649436 accuracy : define function
# epoch 139 loss 0.0016489906710878347
# eval_train evaluate loss 0.0014908466733116379 accuracy : define function
# epoch 140 loss 0.0015560572327517751
# eval_train evaluate loss 0.001558426428766949 accuracy : define function
# epoch 141 loss 0.0015470689517070554
# eval_train evaluate loss 0.0015581100319039577 accuracy : define function
# epoch 142 loss 0.0015800405248526984
# eval_train evaluate loss 0.001554988822447998 accuracy : define function
# epoch 143 loss 0.001544555977556799
# eval_train evaluate loss 0.0015593731025261666 accuracy : define function
# epoch 144 loss 0.001600888166785129
# eval_train evaluate loss 0.0014745363220224964 accuracy : define function
# epoch 145 loss 0.001614430876719807
# eval_train evaluate loss 0.0014787446742237948 accuracy : define function
# epoch 146 loss 0.0016479863439436391
# eval_train evaluate loss 0.001529274803739208 accuracy : define function
# epoch 147 loss 0.0015803787417695927
# eval_train evaluate loss 0.0014565142293794275 accuracy : define function
# epoch 148 loss 0.001563169704159416
# eval_train evaluate loss 0.0014351524913044117 accuracy : define function
# epoch 149 loss 0.0015711130351940199
# eval_train evaluate loss 0.001405661391379284 accuracy : define function
# epoch 150 loss 0.0015293281662639286
# eval_train evaluate loss 0.0014322781057875436 accuracy : define function
# epoch 151 loss 0.0015488395340559975
# eval_train evaluate loss 0.0014296038295211855 accuracy : define function
# epoch 152 loss 0.0015580563053641636
# eval_train evaluate loss 0.001415982060551421 accuracy : define function
# epoch 153 loss 0.0015112521238069036
# eval_train evaluate loss 0.0018277471336021797 accuracy : define function
# epoch 154 loss 0.0016028304990909216
# eval_train evaluate loss 0.0014281370564113692 accuracy : define function
# epoch 155 loss 0.0015370450330091947
# eval_train evaluate loss 0.001572745884316904 accuracy : define function
# epoch 156 loss 0.0015712805620547552
# eval_train evaluate loss 0.0013985166251450887 accuracy : define function
# epoch 157 loss 0.0015467599107286155
# eval_train evaluate loss 0.001415729834593888 accuracy : define function
# epoch 158 loss 0.0015891506119436625
# eval_train evaluate loss 0.0014326905982860766 accuracy : define function
# epoch 159 loss 0.0016102164422523285
# eval_train evaluate loss 0.001472285350110493 accuracy : define function
# epoch 160 loss 0.0015906069354751885
# eval_train evaluate loss 0.0014482604073874875 accuracy : define function
# epoch 161 loss 0.001693399450150944
# eval_train evaluate loss 0.0015591947203710565 accuracy : define function
# epoch 162 loss 0.0015991281756241598
# eval_train evaluate loss 0.0014179365591271155 accuracy : define function
# epoch 163 loss 0.0015908863583107048
# eval_train evaluate loss 0.0014667214153320598 accuracy : define function
# epoch 164 loss 0.0015332905989168073
# eval_train evaluate loss 0.001453070265393871 accuracy : define function
# epoch 165 loss 0.0016013168175565773
# eval_train evaluate loss 0.0014380558885620045 accuracy : define function
# epoch 166 loss 0.0015911121545150986
# eval_train evaluate loss 0.0014588000251105362 accuracy : define function
# epoch 167 loss 0.0015485515963953379
# eval_train evaluate loss 0.001440505529302103 accuracy : define function
# epoch 168 loss 0.0015585414019288189
# eval_train evaluate loss 0.001472333586017198 accuracy : define function
# epoch 169 loss 0.0015149385800390545
# eval_train evaluate loss 0.0013868923007107493 accuracy : define function
# epoch 170 loss 0.0015422716465736948
# eval_train evaluate loss 0.001463734662966497 accuracy : define function
# epoch 171 loss 0.0015887366851041122
# eval_train evaluate loss 0.0014040031202776887 accuracy : define function
# epoch 172 loss 0.001530813159240382
# eval_train evaluate loss 0.0014090656429709895 accuracy : define function
# epoch 173 loss 0.0015664815432704818
# eval_train evaluate loss 0.0014739724452982642 accuracy : define function
# epoch 174 loss 0.0016254613570410258
# eval_train evaluate loss 0.0015214279810063986 accuracy : define function
# epoch 175 loss 0.0015794857250484846
# eval_train evaluate loss 0.0014635939672311296 accuracy : define function
# epoch 176 loss 0.0015513332353890943
# eval_train evaluate loss 0.0013734077558672027 accuracy : define function
# epoch 177 loss 0.0015730405262838216
# eval_train evaluate loss 0.0015900900801157217 accuracy : define function
# epoch 178 loss 0.0015331626445777824
# eval_train evaluate loss 0.001516295660377494 accuracy : define function
# epoch 179 loss 0.0015407414227696275
# eval_train evaluate loss 0.0015816539204540426 accuracy : define function
# epoch 180 loss 0.0015865166979119071
# eval_train evaluate loss 0.0014241870211214938 accuracy : define function
# epoch 181 loss 0.0015730284364657728
# eval_train evaluate loss 0.001439692995531846 accuracy : define function
# epoch 182 loss 0.0015699770275517297
# eval_train evaluate loss 0.001477072681752103 accuracy : define function
# epoch 183 loss 0.0015587505064348676
# eval_train evaluate loss 0.0014387180067862925 accuracy : define function
# epoch 184 loss 0.001503263415122377
# eval_train evaluate loss 0.0014310716199619111 accuracy : define function
# epoch 185 loss 0.001521269476333105
# eval_train evaluate loss 0.001410267459152183 accuracy : define function
# epoch 186 loss 0.001549922433723487
# eval_train evaluate loss 0.001503748658509341 accuracy : define function
# epoch 187 loss 0.0015305039262635382
# eval_train evaluate loss 0.0014590686925603493 accuracy : define function
# epoch 188 loss 0.0015392498054138538
# eval_train evaluate loss 0.0015410198517310531 accuracy : define function
# epoch 189 loss 0.001510886651804365
# eval_train evaluate loss 0.001367704817719424 accuracy : define function
# epoch 190 loss 0.00153482329784962
# eval_train evaluate loss 0.001495458603551639 accuracy : define function
# epoch 191 loss 0.0015594521676426502
# eval_train evaluate loss 0.0015053780898868815 accuracy : define function
# epoch 192 loss 0.0014982287174285349
# eval_train evaluate loss 0.0013907203188430128 accuracy : define function
# epoch 193 loss 0.0015213624026918255
# eval_train evaluate loss 0.0015006353314131944 accuracy : define function
# epoch 194 loss 0.0015203021319040945
# eval_train evaluate loss 0.0014504592686738651 accuracy : define function
# epoch 195 loss 0.001514902757133232
# eval_train evaluate loss 0.001434905755979968 accuracy : define function
# epoch 196 loss 0.0015624346421795217
# eval_train evaluate loss 0.0013719188655837815 accuracy : define function
# epoch 197 loss 0.0014948881180859657
# eval_train evaluate loss 0.0013615225047331804 accuracy : define function
# epoch 198 loss 0.001536695983385973
# eval_train evaluate loss 0.0015166069627669987 accuracy : define function
# epoch 199 loss 0.0015190229690355708
# eval_train evaluate loss 0.0013622232841383388 accuracy : define function

# %%
tgts = None
preds = None
with torch.no_grad():
    for data_batch in test_loader:
        data_in, tgt = data_batch
        data_in = data_in.to(device)
        tgt = tgt.numpy()
        out = predictor.forward(data_in).cpu().numpy()
        if preds is None:
            preds = out
            tgts = tgt
        else:
            preds = np.concatenate((preds, out), axis=0)
            tgts = np.concatenate((tgts, tgt), axis=0)
preds = preds.reshape(-1)
tgts = tgts.reshape(-1)

# %% [markdown]
# ## Check Accuracy
# * normalize once : 상승, 하락으로만 정확도 평가, 77 %
# * normalize twice : 상승, 하락으로만 정확도 평가, 71 %

# %%
# normalize once
sum1 = np.sum((preds > 0) & (tgts > 0))
sum2 = np.sum((preds < 0) & (tgts < 0))
print(sum1, np.sum(tgts>0))
print(sum2, np.sum(tgts<0))
print(len(preds), sum1+sum2, 1.0*(sum1+sum2)/len(preds))
# Out:
# 370 523
# 438 521
# 1050 808 0.7695238095238095

# %%
# normalize twice
sum1 = np.sum((preds > 0) & (tgts > 0))
sum2 = np.sum((preds < 0) & (tgts < 0))
print(sum1, np.sum(tgts>0))
print(sum2, np.sum(tgts<0))
print(len(preds), sum1+sum2, 1.0*(sum1+sum2)/len(preds))
# Out:
# 343 523
# 401 521
# 1050 744 0.7085714285714285

# %%
# normalize once
xs = range(len(preds))
fig1 = plt.figure(figsize=(13,3))
plt.plot(xs, preds, color='r')
plt.plot(xs, tgts, color='b')
plt.show()

# %%
# normalize twice
xs = range(len(preds))
fig1 = plt.figure(figsize=(13,3))
plt.plot(xs, preds, color='r')
plt.plot(xs, tgts, color='b')
plt.show()

# %%
x_lim = 30
plt.plot(xs[:x_lim], preds[:x_lim], color='r')
plt.plot(xs[:x_lim], tgts[:x_lim], color='b')
plt.show()

# %%
## CHECK data
ys_test = tensor_tgt[n_test:n_test*2]
xs_test = range(len(ys_test))
fig1 = plt.figure(figsize=(13,3))
plt.plot(xs_test, ys_test, color='r')
plt.show()

# %%
preds
# Out:
# array([0.00405974, 0.00401071, 0.00401111, 0.00399112, 0.00400899,
#        0.00401835, 0.00402547, 0.00400957, 0.00400952, 0.00406704,
#        0.00407123, 0.00410094, 0.00416425, 0.00414258, 0.00413061,
#        0.00416722, 0.0042227 , 0.0041813 , 0.00421616, 0.00415647,
#        0.00408907, 0.00408076, 0.00411696, 0.00407618, 0.00404733,
#        0.00400664, 0.00400045, 0.00399909, 0.00399198, 0.00404403,
#        0.00409118, 0.0040611 , 0.00406437, 0.00409822, 0.00409434,
#        0.00412223, 0.00411687, 0.00412879, 0.00411717, 0.00409971,
#        0.0040956 , 0.00407412, 0.00399904, 0.00399181, 0.00400749,
#        0.00401235, 0.00401731, 0.00403453, 0.00403524, 0.00403154,
#        0.00408459, 0.00405371, 0.00399919, 0.00398572, 0.00396761,
#        0.00393918, 0.0039205 , 0.00392819, 0.00390763, 0.00392944,
#        0.00389209, 0.00396236, 0.00395109, 0.00394887, 0.0040023 ,
#        0.00404651, 0.0040491 , 0.00405893, 0.00412634, 0.00411597,
#        0.00413144, 0.0041013 , 0.0040574 , 0.00400037, 0.00404997,
#        0.00404798, 0.00404342, 0.00405581, 0.0040468 , 0.00402949,
#        0.00404977, 0.00407192, 0.00405877, 0.00408831, 0.00409527,
#        0.00407947, 0.00410034, 0.00416865, 0.0041762 , 0.00414558,
#        0.00409932, 0.00410418, 0.00407578, 0.00409504, 0.00407871,
#        0.00405198, 0.00405198, 0.00406366, 0.00402003, 0.00401085,
#        0.00399526, 0.00402923, 0.00401456, 0.00399513, 0.00400158,
#        0.00402591, 0.00403285, 0.0040707 , 0.0040706 , 0.0040924 ,
#        0.00405926, 0.00409254, 0.00408979, 0.00409608, 0.00409823,
#        0.00407484, 0.00409879, 0.00410734, 0.00409453, 0.00408487,
#        0.00408941, 0.00408816, 0.00409272, 0.00408458, 0.00405383,
#        0.0040676 , 0.0040708 , 0.00403725, 0.00403811, 0.00406085,
#        0.00403436, 0.00400783, 0.00402143, 0.00408232, 0.00408902,
#        0.0041149 , 0.00407799, 0.00401324, 0.0040571 , 0.0040678 ,
#        0.00404224, 0.00401624, 0.00399916, 0.00399043, 0.00399519,
#        0.00398698, 0.00398082, 0.00397393, 0.00400008, 0.00400423,
#        0.0040656 , 0.0040521 , 0.00405755, 0.004032  , 0.00403589,
#        0.00403594, 0.00402105, 0.00399895, 0.00401896, 0.00403213,
#        0.00407174, 0.00409147, 0.00409648, 0.00409091, 0.00408695,
#        0.00405783, 0.0040679 , 0.0040453 , 0.00404556, 0.00403452,
#        0.00402884, 0.00404138, 0.00404481, 0.00407492, 0.0040821 ,
#        0.00404855, 0.00409811, 0.0040939 , 0.00410442, 0.00407117,
#        0.00405707, 0.00405512, 0.00404365, 0.00405994, 0.00404546,
#        0.00407071, 0.00408855, 0.00410874, 0.00410976, 0.00407319,
#        0.00404496, 0.00403682, 0.00405477, 0.00405501, 0.00404167,
#        0.00403869, 0.00403995, 0.00408747, 0.0041018 , 0.00412072,
#        0.00413196, 0.00415049, 0.00412737, 0.00411809, 0.0041104 ,
#        0.00412727, 0.00410155, 0.00412502, 0.00415012, 0.00412811,
#        0.00416334, 0.00417558, 0.00414627, 0.00410555, 0.00407509,
#        0.00406896, 0.00400977, 0.00406275, 0.00403685, 0.00407949,
#        0.00407729, 0.00408629, 0.00410625], dtype=float32)

# %%
df1.index
# Out:
# Index(['2000-10-20', '2000-10-21', '2000-10-23', '2000-10-24', '2000-10-25',
#        '2000-10-26', '2000-10-27', '2000-10-28', '2000-10-30', '2000-10-31',
#        ...
#        '2021-04-02', '2021-04-05', '2021-04-06', '2021-04-07', '2021-04-08',
#        '2021-04-09', '2021-04-12', '2021-04-13', '2021-04-14', '2021-04-15'],
#       dtype='object', name='date', length=5366)
