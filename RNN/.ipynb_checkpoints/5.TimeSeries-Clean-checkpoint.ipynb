# %% [markdown]
# ### Time Series (차원size 및 view 처리 이해)
# > Seqence 7개 묶음으로 긴 날짜를 Window 이동하면서 데이터 파악
#
# > 다중(Window 이동 O) many-to-*One [ 최종출력은 마지막 만 ]
#
# > 특징 factor는 5개 (ex.시, 고, 저, 종, 거래량 )
#
# > Window Dataset 로직 → 함수로
#
# > 다중 네트워크(FC추가) → Class로 구현

# %%
import torch
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

# Random seed to make results deterministic and reproducible 
torch.manual_seed(0)

# %%
def minmax_scaler(data):
    numerator = data - np.min(data, 0)
    denominator = np.max(data, 0) - np.min(data, 0)
    return numerator / (denominator + 1e-7)

# %% [markdown]
# ### Window Dataset 함수

# %%
def build_dataset(time_series, seq_length):
    dataX = []
    dataY = []
    for i in range(0, len(time_series) - seq_length):
        _x = time_series[i:i + seq_length, :]
        _y = time_series[i + seq_length, [-1]]  #    * many-to-one 이기 때문에 마지막 1개 값만!!
        dataX.append(_x)
        dataY.append(_y)
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# #### 데이터 로드

# %%
# load
xy = np.loadtxt("data-02-stock_daily.csv", delimiter=",")
xy = xy[::-1]  # reverse order
print(xy.shape)
print(xy[:3])
# Out:
# (732, 5)
# [[  568.00257    568.00257    552.922516 13100.         558.462551]
#  [  561.202549   566.43259    558.672539 41200.         559.992565]
#  [  566.892592   567.002574   556.932537 10800.         556.972503]]

# %% [markdown]
# #### many-to-many와 준비 데이터 셋 부터 다름 : Y가 1이 됨

# %% [markdown]
# #### 데이터 작업
# > seq_length는 데이터 작업 시에만 필요(네트워크 모델쪽과 관련X)

# %%
seq_length = 7  

# Split
train_size = int(len(xy) * 0.7)
train_set = xy[0:train_size]
test_set = xy[train_size - seq_length:]  # train이 train_size만큼 진행 X 
print('단순 Split한 Train_size :', train_size)                                                     

# Scaling
train_set = minmax_scaler(train_set)
test_set = minmax_scaler(test_set)

# Window Dataset 처리
trainX, trainY = build_dataset(train_set, seq_length)
testX, testY = build_dataset(test_set, seq_length)

# Tensor 변환
trainX_tensor = torch.FloatTensor(trainX)  #            512 - 7 = 505 만큼의 window 묶음(7단위)이 train_X로 준비 될 것
trainY_tensor = torch.FloatTensor(trainY)
testX_tensor = torch.FloatTensor(testX)    # (732-505) -7 = 220 만큼의 window 묶음(7단위)이 test_X로 준비 될 것
testY_tensor = torch.FloatTensor(testY)
# Out:
# 단순 Split한 Train_size : 512

# %%
print(trainX_tensor.shape)
print(trainY_tensor.shape)
print(testX_tensor.shape)
print(testY_tensor.shape)
# Out:
# torch.Size([505, 7, 5])
# torch.Size([505, 1])
# torch.Size([220, 7, 5])
# torch.Size([220, 1])

# %% [markdown]
# #### 단어사전/원핫 특징을 제외하고는 Window이동에 따른 데이터 셋 [170개, 10개묶음] 준비는 X, Y 동일
# - ( Batch = 1 )
# - 전체 row (Window 이동 횟수) = 505
# - Seq Windiow : 7
# - input_size (특징차원, 단어사전/원핫, input node) : 5   ※ 이게 Data 특징이 될 것 : 시,고,저,종,거래량,환율,CPI,PPI,PMI,US10y 등
# - output_size : 1 (to-one)  ※ to-many라면 7

# %% [markdown]
# #### many-to-many가 이니면 최종  Output은 Window 마지막 작업에만 출력
# ##### Window 마지막 이전 멤버들은 _status 만 recurrent  시킴

# %%
input_dim = 5                # input size : 입력층 노드 수
hidden_dim = 13         # hidden size : 중간(은닉)층 노드 수 (Next Layer Input Size와 같게)
output_dim = 1            # output size : 출력 노드 수

# # 일반 변수로 작성하면 이렇게
# data_dim     = trainX_tensor.shape[-1]    # X의 마지막 차원
# output_dim = trainY_tensor.shape[-1]    # Y의 마지막 차원

class Net(torch.nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim, layers): # ( 5, 10, 1, layer )
        super(Net, self).__init__()
        self.rnn = torch.nn.LSTM(input_dim, hidden_dim, num_layers=layers, batch_first=True) # hidden이 다음 input이 되면 됨
        self.fc = torch.nn.Linear(hidden_dim, output_dim, bias=True)       

    def forward(self, x):
        x, _status = self.rnn(x)
        x = self.fc(x) 
        return x    
    
net = Net(input_dim, hidden_dim, output_dim, layers=1) # layers 숫자만 바꾸서  멀티층으로 늘릴 수도 있다

# %%
learning_rate = 0.01
iterations = 500

# loss & optimizer setting
criterion = torch.nn.MSELoss()
optimizer = optim.Adam(net.parameters(), lr=learning_rate)

for i in range(iterations):
    optimizer.zero_grad()
    print("trainX_tensor.shape : ", trainX_tensor.shape)
    outputs = net.forward(trainX_tensor)
    print("outputs[:,-1].shape : ", outputs[:,-1].shape)
    
    # many-to-one 인 경우는 Window 맨 마지막 데이터만 활용하면 된다.
    loss = criterion(outputs[:,-1], trainY_tensor) 
    loss.backward()
    optimizer.step()
    print("epoch[",i,"]" , round(loss.item(),5))
    
print("outputs.shape :", outputs.shape)
print("trainY_tensor.shape :", trainY_tensor.shape)
# Out:
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 0 ] 0.13223
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 1 ] 0.10501
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 2 ] 0.08621
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 3 ] 0.07268
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 4 ] 0.06346
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 5 ] 0.05817
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 6 ] 0.05561
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 7 ] 0.05334
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 8 ] 0.04952
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 9 ] 0.04384
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 10 ] 0.03708
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 11 ] 0.03027
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 12 ] 0.0241
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 13 ] 0.01877
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 14 ] 0.01417
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 15 ] 0.0101
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 16 ] 0.0066
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 17 ] 0.00417
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 18 ] 0.00361
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 19 ] 0.00489
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 20 ] 0.00636
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 21 ] 0.00726
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 22 ] 0.00791
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 23 ] 0.00816
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 24 ] 0.00758
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 25 ] 0.00629
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 26 ] 0.00484
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 27 ] 0.00372
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 28 ] 0.00309
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 29 ] 0.00282
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 30 ] 0.00275
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 31 ] 0.00281
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 32 ] 0.00296
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 33 ] 0.00318
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 34 ] 0.00343
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 35 ] 0.00361
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 36 ] 0.00368
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 37 ] 0.00361
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 38 ] 0.00345
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 39 ] 0.00324
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 40 ] 0.00303
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 41 ] 0.00283
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 42 ] 0.00265
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 43 ] 0.0025
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 44 ] 0.00238
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 45 ] 0.00233
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 46 ] 0.00234
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 47 ] 0.0024
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[
] 0.00137
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 292 ] 0.00137
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 293 ] 0.00137
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 294 ] 0.00137
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 295 ] 0.00137
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 296 ] 0.00137
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 297 ] 0.00136
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 298 ] 0.00136
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 299 ] 0.00136
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 300 ] 0.00136
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 301 ] 0.00136
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 302 ] 0.00136
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 303 ] 0.00136
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 304 ] 0.00135
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 305 ] 0.00135
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 306 ] 0.00135
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 307 ] 0.00135
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 308 ] 0.00135
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 309 ] 0.00135
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 310 ] 0.00135
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 311 ] 0.00135
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 312 ] 0.00134
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 313 ] 0.00134
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 314 ] 0.00134
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 315 ] 0.00134
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 316 ] 0.00134
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 317 ] 0.00134
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 318 ] 0.00134
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 319 ] 0.00134
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 320 ] 0.00133
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 321 ] 0.00133
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 322 ] 0.00133
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 323 ] 0.00133
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 324 ] 0.00133
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 325 ] 0.00133
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 326 ] 0.00133
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 327 ] 0.00133
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 328 ] 0.00132
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 329 ] 0.00132
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 330 ] 0.00132
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 331 ] 0.00132
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 332 ] 0.00132
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 333 ] 0.00132
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 334 ] 0.00132
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 335 ] 0.00132
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 336 ] 0.00132
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 337 ] 0.00131
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 338 ] 0.00131
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 339 ] 0.00131
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 340 ] 0.00131
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 341 ] 0.00131
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 342 ] 0.00131
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 343 ] 0.00131
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 344 ] 0.00131
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 345 ] 0.00131
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 346 ] 0.00131
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 347 ] 0.0013
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 348 ] 0.0013
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 349 ] 0.0013
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 350 ] 0.0013
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 351 ] 0.0013
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 352 ] 0.0013
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 353 ] 0.0013
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 354 ] 0.0013
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 355 ] 0.0013
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 356 ] 0.0013
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 357 ] 0.00129
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 358 ] 0.00129
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 359 ] 0.00129
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 360 ] 0.00129
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 361 ] 0.00129
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 362 ] 0.00129
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 363 ] 0.00129
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 364 ] 0.00129
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 365 ] 0.00129
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 366 ] 0.00129
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 367 ] 0.00128
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 368 ] 0.00128
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 369 ] 0.00128
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 370 ] 0.00128
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 371 ] 0.00128
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 372 ] 0.00128
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 373 ] 0.00128
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 374 ] 0.00128
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 375 ] 0.00128
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 376 ] 0.00128
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 377 ] 0.00128
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 378 ] 0.00128
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 379 ] 0.00127
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 380 ] 0.00127
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 381 ] 0.00127
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 382 ] 0.00127
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 383 ] 0.00127
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 384 ] 0.00127
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 385 ] 0.00127
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 386 ] 0.00127
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 387 ] 0.00127
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 388 ] 0.00127
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 389 ] 0.00127
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 390 ] 0.00127
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 391 ] 0.00126
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 392 ] 0.00126
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 393 ] 0.00126
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 394 ] 0.00126
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 395 ] 0.00126
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 396 ] 0.00126
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 397 ] 0.00126
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 398 ] 0.00126
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 399 ] 0.00126
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 400 ] 0.00126
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 401 ] 0.00126
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 402 ] 0.00126
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 403 ] 0.00126
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 404 ] 0.00126
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 405 ] 0.00125
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 406 ] 0.00125
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 407 ] 0.00125
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 408 ] 0.00125
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 409 ] 0.00125
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 410 ] 0.00125
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 411 ] 0.00125
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 412 ] 0.00125
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 413 ] 0.00125
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 414 ] 0.00125
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 415 ] 0.00125
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 416 ] 0.00125
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 417 ] 0.00125
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 418 ] 0.00125
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 419 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 420 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 421 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 422 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 423 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 424 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 425 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 426 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 427 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 428 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 429 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 430 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 431 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 432 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 433 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 434 ] 0.00124
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 435 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 436 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 437 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 438 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 439 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 440 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 441 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 442 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 443 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 444 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 445 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 446 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 447 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 448 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 449 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 450 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 451 ] 0.00123
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 452 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 453 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 454 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 455 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 456 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 457 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 458 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 459 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 460 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 461 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 462 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 463 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 464 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 465 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 466 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 467 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 468 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 469 ] 0.00122
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 470 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 471 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 472 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 473 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 474 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 475 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 476 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 477 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 478 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 479 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 480 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 481 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 482 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 483 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 484 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 485 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 486 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 487 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 488 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 489 ] 0.00121
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 490 ] 0.0012
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 491 ] 0.0012
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 492 ] 0.0012
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 493 ] 0.0012
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 494 ] 0.0012
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 495 ] 0.0012
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 496 ] 0.0012
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 497 ] 0.0012
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 498 ] 0.0012
# trainX_tensor.shape :  torch.Size([505, 7, 5])
# outputs[:,-1].shape :  torch.Size([505, 1])
# epoch[ 499 ] 0.0012
# outputs.shape : torch.Size([505, 7, 1])
# trainY_tensor.shape : torch.Size([505, 1])

# %% [markdown]
# ### Test 부분

# %%
plt.plot(testY)
plt.plot(net(testX_tensor).data.numpy())
plt.legend(['original', 'prediction'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-10aa2d35e198> in <module>
#       1 plt.plot(testY)
# ----> 2 plt.plot(net(testX_tensor).data.numpy())
#       3 plt.legend(['original', 'prediction'])
#       4 plt.show()
#
# /home/adminuser/.local/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# /home/adminuser/.local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# /home/adminuser/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# /home/adminuser/.local/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     400                              f"have shapes {x.shape} and {y.shape}")
#     401         if x.ndim > 2 or y.ndim > 2:
# --> 402             raise ValueError(f"x and y can be no greater than 2-D, but have "
#     403                              f"shapes {x.shape} and {y.shape}")
#     404         if x.ndim == 1:
#
# ValueError: x and y can be no greater than 2-D, but have shapes (220,) and (220, 7, 1)
